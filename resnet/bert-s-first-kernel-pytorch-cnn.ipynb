# %%
# %env JOBLIB_TEMP_FOLDER=/tmp
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision import models
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os
import cv2
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
import time


class ImgDataset(Dataset):
    def __init__(self, x, y=None, transform=None):
        self.x = x
        # label is required to be a LongTensor
        self.y = y
        if y is not None:
            self.y = torch.LongTensor(y)
        self.transform = transform
    def __len__(self):
        return len(self.x)
    def __getitem__(self, index):
        X = self.x[index]
        if self.transform is not None:
            X = self.transform(X)
        if self.y is not None:
            Y = self.y[index]
            return X, Y
        else:
            return X
# Out:
# env: JOBLIB_TEMP_FOLDER=/tmp

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
# # Read Files
# df = pd.read_csv('/kaggle/input/shopee-product-detection-open/train.csv',encoding="utf-8", dtype=str, nrows=20000)	
# x = np.zeros((len(df), 128, 128, 3),dtype=np.uint8)
# y = np.zeros((len(df)),dtype=np.uint8)
# filename = df['filename']
# category = df['category']
# for i in range(len(df)):
#     if len(category[i]) == 1:
#         category[i] = '0'+category[i]
#     if i % 100 == 0:
#         print(i, '/kaggle/input/shopee-product-detection-open/train/train/train/'+category[i]+'/'+filename[i])
#     img = cv2.imread('/kaggle/input/shopee-product-detection-open/train/train/train/'+category[i]+'/'+filename[i])
#     x[i, :, :] = cv2.resize(img,(128, 128))
#     y[i] = category[i]

# %%
# Read Files
df = pd.read_csv('/kaggle/input/shopee-product-detection-open/train.csv',encoding="utf-8", dtype=str)	
x = np.zeros((len(df), 128, 128, 3),dtype=np.uint8)
y = np.zeros((len(df)),dtype=np.uint8)
filename = df['filename']
category = df['category']
for i in range(len(df)):
    if len(category[i]) == 1:
        category[i] = '0'+category[i]
    if i % 100 == 0:
        print(i, '/kaggle/input/shopee-product-detection-open/train/train/train/'+category[i]+'/'+filename[i])
    img = cv2.imread('/kaggle/input/shopee-product-detection-open/train/train/train/'+category[i]+'/'+filename[i])
    x[i, :, :] = cv2.resize(img,(128, 128))
    y[i] = category[i]

x_train, x_val, y_train, y_val = train_test_split(x,y,test_size=0.2,stratify=y)



# training 時做 data augmentation
train_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomHorizontalFlip(), # 隨機將圖片水平翻轉
    transforms.RandomRotation(15), # 隨機旋轉圖片
    transforms.ToTensor(), # 將圖片轉成 Tensor，並把數值 normalize 到 [0,1] (data normalization)
])
# testing 時不需做 data augmentation
test_transform = transforms.Compose([
    transforms.ToPILImage(),                                    
    transforms.ToTensor(),
])


batch_size = 128
train_set = ImgDataset(x_train, y_train, train_transform)
val_set = ImgDataset(x_val, y_val, test_transform)
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False)



# model = Classifier().cuda()
model = models.resnet101(pretrained=True).cuda()
loss = nn.CrossEntropyLoss() # 因為是 classification task，所以 loss 使用 CrossEntropyLoss
optimizer = torch.optim.Adam(model.parameters(), lr=0.001) # optimizer 使用 Adam
num_epoch = 30

for epoch in range(num_epoch):
    epoch_start_time = time.time()
    train_acc = 0.0
    train_loss = 0.0
    val_acc = 0.0
    val_loss = 0.0

    model.train() # 確保 model 是在 train model (開啟 Dropout 等...)
    for i, data in enumerate(train_loader):
        optimizer.zero_grad() # 用 optimizer 將 model 參數的 gradient 歸零
        train_pred = model(data[0].cuda()) # 利用 model 得到預測的機率分佈 這邊實際上就是去呼叫 model 的 forward 函數
        batch_loss = loss(train_pred, data[1].cuda()) # 計算 loss （注意 prediction 跟 label 必須同時在 CPU 或是 GPU 上）
        batch_loss.backward() # 利用 back propagation 算出每個參數的 gradient
        optimizer.step() # 以 optimizer 用 gradient 更新參數值

        train_acc += np.sum(np.argmax(train_pred.cpu().data.numpy(), axis=1) == data[1].numpy())
        train_loss += batch_loss.item()

    model.eval()
    with torch.no_grad():
        for i, data in enumerate(val_loader):
            val_pred = model(data[0].cuda())
            batch_loss = loss(val_pred, data[1].cuda())

            val_acc += np.sum(np.argmax(val_pred.cpu().data.numpy(), axis=1) == data[1].numpy())
            val_loss += batch_loss.item()

        #將結果 print 出來
        print('[%03d/%03d] %2.2f sec(s) Train Acc: %3.6f Loss: %3.6f | Val Acc: %3.6f loss: %3.6f' % \
            (epoch + 1, num_epoch, time.time()-epoch_start_time, \
             train_acc/train_set.__len__(), train_loss/train_set.__len__(), val_acc/val_set.__len__(), val_loss/val_set.__len__()))


PATH = './resNet.pth'
torch.save(model.state_dict(), PATH)

# %%
# Do Prediction

# Read Test File
# Read Files
df_test = pd.read_csv('/kaggle/input/shopee-product-detection-open/test.csv',encoding="utf-8", dtype=str)	
test_x = np.zeros((len(df_test), 128, 128, 3),dtype=np.uint8)
# y_test = np.zeros((len(df_test)),dtype=np.uint8)
filename = df_test['filename']
# category = df_test['category']
for i in range(len(df_test)):
    if i % 100 == 0:
        print(i, '/kaggle/input/shopee-product-detection-open/test/test/test/'+filename[i])
    img = cv2.imread('/kaggle/input/shopee-product-detection-open/test/test/test/'+filename[i])
    test_x[i, :, :] = cv2.resize(img,(128, 128))
#     y_test[i] = category[i]

# testing 時不需做 data augmentation
test_transform = transforms.Compose([
    transforms.ToPILImage(),                                    
    transforms.ToTensor(),
])

batch_size = 128
test_set = ImgDataset(test_x, transform=test_transform)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False)


model = models.resnet101(pretrained=True).cuda()
model.load_state_dict(torch.load('/kaggle/input/resnet-model/resNet.pth'))
model.eval()


prediction = []
with torch.no_grad():
    for i, data in enumerate(test_loader):
        test_pred = model(data.cuda())
        test_label = np.argmax(test_pred.cpu().data.numpy(), axis=1)
        for y in test_label:
            if len(str(y)) == 1:
                y = '0'+str(y)
            prediction.append(y)
            
            
            
            
#將結果寫入 csv 檔
# with open("predict.csv", 'w') as f:
#     f.write('Id,Category\n')
#     for i, y in  enumerate(prediction):
#         f.write('{},{}\n'.format(i, y))

df = pd.DataFrame(list(zip(filename, prediction)), 
               columns =['filename', 'category'])
df.to_csv("predict.csv",encoding="utf_8_sig", index=False)
print('finished')
# Out:
# 0 /kaggle/input/shopee-product-detection-open/test/test/test/fd663cf2b6e1d7b02938c6aaae0a32d2.jpg
# 100 /kaggle/input/shopee-product-detection-open/test/test/test/65e04aeb8a47dfb6ddace83ac36eb066.jpg
# 200 /kaggle/input/shopee-product-detection-open/test/test/test/c4fb5395ccbb386eefbe96aae6d5e060.jpg
# 300 /kaggle/input/shopee-product-detection-open/test/test/test/8eaca4ab9a2b78af894f70c1f7a2efe7.jpg
# 400 /kaggle/input/shopee-product-detection-open/test/test/test/b9909277fb2c07de52f22d7f41745d4a.jpg
# 500 /kaggle/input/shopee-product-detection-open/test/test/test/3a23ef555ced0eab4428434db1e21b37.jpg
# 600 /kaggle/input/shopee-product-detection-open/test/test/test/331d907e9083c66aa835a63914c0bcb3.jpg
# 700 /kaggle/input/shopee-product-detection-open/test/test/test/1146cab54204f63db4ad698ce908975f.jpg
# 800 /kaggle/input/shopee-product-detection-open/test/test/test/f450adad3c829529a37051012941d3a3.jpg
# 900 /kaggle/input/shopee-product-detection-open/test/test/test/094def548a66dc564108ddb5cb9af59b.jpg
# 1000 /kaggle/input/shopee-product-detection-open/test/test/test/ca875e297d4e6ed407a1a1376b8603d0.jpg
# 1100 /kaggle/input/shopee-product-detection-open/test/test/test/737f85cd41b96ca2e000dd794689d260.jpg
# 1200 /kaggle/input/shopee-product-detection-open/test/test/test/90cc549c69d231a24f2d8e304874530b.jpg
# 1300 /kaggle/input/shopee-product-detection-open/test/test/test/5980b27bfa1ccef775e3d0ee841f4d92.jpg
# 1400 /kaggle/input/shopee-product-detection-open/test/test/test/b7939c39d5c7c2544c4ee9067f6389ff.jpg
# 1500 /kaggle/input/shopee-product-detection-open/test/test/test/921e8ef0bdef44e96a616e89d1043bd0.jpg
# 1600 /kaggle/input/shopee-product-detection-open/test/test/test/4b4dd72326f09a5b7eb0a4090f89bec8.jpg
# 1700 /kaggle/input/shopee-product-detection-open/test/test/test/0bd809af0286048b878b13c873302c96.jpg
# 1800 /kaggle/input/shopee-product-detection-open/test/test/test/a9647c47aeb86e7c706beeb653c74c63.jpg
# 1900 /kaggle/input/shopee-product-detection-open/test/test/test/fe4b4254d7a2d3e304b7c438d2f4e49d.jpg
# 2000 /kaggle/input/shopee-product-detection-open/test/test/test/bb9ed11a7da875d7477747f40df2ec57.jpg
# 2100 /kaggle/input/shopee-product-detection-open/test/test/test/f9935cdcea87cc4e84c551c717ea00ce.jpg
# 2200 /kaggle/input/shopee-product-detection-open/test/test/test/cfa838556fde2cf2419d260ba9f9dd9c.jpg
# 2300 /kaggle/input/shopee-product-detection-open/test/test/test/8d510f6c42e4b10e36fcefa8595f3949.jpg
# 2400 /kaggle/input/shopee-product-detection-open/test/test/test/07ea83c345788c38e8e48e00f1023f08.jpg
# 2500 /kaggle/input/shopee-product-detection-open/test/test/test/57f463da2fc960cbac1041e55c932289.jpg
# 2600 /kaggle/input/shopee-product-detection-open/test/test/test/c060d98a86cd547ceabd33a4c1088768.jpg
# 2700 /kaggle/input/shopee-product-detection-open/test/test/test/fba37bbc2a75c33c40829d7b6beeb12b.jpg
# 2800 /kaggle/input/shopee-product-detection-open/test/test/test/eb8da4d6c53461330ddb2503eb382b5f.jpg
# 2900 /kaggle/input/shopee-product-detection-open/test/test/test/d19f7f19a5e9b3fe9844feaa338ef5a2.jpg
# 3000 /kaggle/input/shopee-product-detection-open/test/test/test/ad71e07d274a40d9b8f0f6962bcbd5a8.jpg
# 3100 /kaggle/input/shopee-product-detection-open/test/test/test/9aa3f621ef7b4f10ca23a5345f3e0f2c.jpg
# 3200 /kaggle/input/shopee-product-detection-open/test/test/test/d50583fc903bd1dbde8a8331bc575b65.jpg
# 3300 /kaggle/input/shopee-product-detection-open/test/test/test/3c39fe72cab142e86d3f33e4e4984c9f.jpg
# 3400 /kaggle/input/shopee-product-detection-open/test/test/test/309d85daabf89726843ac40bb214a3d9.jpg
# 3500 /kaggle/input/shopee-product-detection-open/test/test/test/9d49cd32861828045f2c6a72aa9e32a5.jpg
# 3600 /kaggle/input/shopee-product-detection-open/test/test/test/6a75d9af555119327a3b310320ca445b.jpg
# 3700 /kaggle/input/shopee-product-detection-open/test/test/test/21ab43739450139d4a69472f0b1cbabf.jpg
# 3800 /kaggle/input/shopee-product-detection-open/test/test/test/8039fc66b3b8bdbd39625aee2e0bc9b8.jpg
# 3900 /kaggle/input/shopee-product-detection-open/test/test/test/8b93d68b50aefbbfa084a0a1a9ed5f3d.jpg
# 4000 /kaggle/input/shopee-product-detection-open/test/test/test/18611f55a9727fd6c4b5da9e155f4447.jpg
# 4100 /kaggle/input/shopee-product-detection-open/test/test/test/d0c56f67482e11df5a6e38d3e5b75070.jpg
# 4200 /kaggle/input/shopee-product-detection-open/test/test/test/720450d607e4fe5c86615503780fac49.jpg
# 4300 /kaggle/input/shopee-product-detection-open/test/test/test/4f21311eed1be9db49c3be63c4bb6129.jpg
# 4400 /kaggle/input/shopee-product-detection-open/test/test/test/6439377b095af6b892bd8adb55f033cb.jpg
# 4500 /kaggle/input/shopee-product-detection-open/test/test/test/c9bbc124377a13917762a4215ab2f534.jpg
# 4600 /kaggle/input/shopee-product-detection-open/test/test/test/6f908c3f9141fa6b296733c5e14adf58.jpg
# 4700 /kaggle/input/shopee-product-detection-open/test/test/test/23a6cbf8a6bb2be38af5dde0755c2acd.jpg
# 4800 /kaggle/input/shopee-product-detection-open/test/test/test/4e0c44bd769d3f12ab2b10c25ae4282d.jpg
# 4900 /kaggle/input/shopee-product-detection-open/test/test/test/485d7fc02a1828e33f93535ebcf0d932.jpg
# 5000 /kaggle/input/shopee-product-detection-open/test/test/test/39724bc90ce92db38caeaa6e44c4bf60.jpg
# 5100 /kaggle/input/shopee-product-detection-open/test/test/test/6e4db8a3c613bb4e1fb480c93e449373.jpg
# 5200 /kaggle/input/shopee-product-detection-open/test/test/test/7658654923ad4a71e4fda47d84f82bb9.jpg
# 5300 /kaggle/input/shopee-product-detection-open/test/test/test/f15071b133910a46fe3564af71441c46.jpg
# 5400 /kaggle/input/shopee-product-detection-open/test/test/test/1c280408de6c7231d6022eec8a829411.jpg
# 5500 /kaggle/input/shopee-product-detection-open/test/test/test/241d5939e9cf95d192d7acfdbae23057.jpg
# 5600 /kaggle/input/shopee-product-detection-open/test/test/test/4a8a53ff82d629cb0f32756b5b15bf50.jpg
# 5700 /kaggle/input/shopee-product-detection-open/test/test/test/e029870f637070a9a6690466f19a3e7f.jpg
# 5800 /kaggle/input/shopee-product-detection-open/test/test/test/4827da9aff6aa216ffae719c4f5d8c48.jpg
# 5900 /kaggle/input/shopee-product-detection-open/test/test/test/210ada2b892d09c25d0a094dac4c161d.jpg
# 6000 /kaggle/input/shopee-product-detection-open/test/test/test/3931d86ed4e72b979224cbabfdba37b4.jpg
# 6100 /kaggle/input/shopee-product-detection-open/test/test/test/722cd020842694fded15c24612d4e9c1.jpg
# 6200 /kaggle/input/shopee-product-detection-open/test/test/test/d4738a693d0290141926ae5d26b45615.jpg
# 6300 /kaggle/input/shopee-product-detection-open/test/test/test/bc9ee4b68a2c03f15cdf61e208c0990b.jpg
# 6400 /kaggle/input/shopee-product-detection-open/test/test/test/92b770c0cb2ccf8452102987d2c9dab9.jpg
# 6500 /kaggle/input/shopee-product-detection-open/test/test/test/deaa103bf09540ac4d58916369871d0e.jpg
# 6600 /kaggle/input/shopee-product-detection-open/test/test/test/dbb38b639fad2fb4b357dc1bb89ec03f.jpg
# 6700 /kaggle/input/shopee-product-detection-open/test/test/test/43298131eade08d9e3ba3aaffae86693.jpg
# 6800 /kaggle/input/shopee-product-detection-open/test/test/test/2945d3da4ab28b80e7752b6ec6fc24c6.jpg
# 6900 /kaggle/input/shopee-product-detection-open/test/test/test/d0dc193492fb7c072309c2976bbadb6d.jpg
# 7000 /kaggle/input/shopee-product-detection-open/test/test/test/10c32e95e86775b2af95b303bc87c530.jpg
# 7100 /kaggle/input/shopee-product-detection-open/test/test/test/8f9bdc92fbc9213423da8a51a944fa60.jpg
# 7200 /kaggle/input/shopee-product-detection-open/test/test/test/ffef86f7872cd020992e00b7cf6585c7.jpg
# 7300 /kaggle/input/shopee-product-detection-open/test/test/test/4fe9af761d8dd1e02e390fd573d8bbc5.jpg
# 7400 /kaggle/input/shopee-product-detection-open/test/test/test/1421742df5f76b064d8c1975097a2825.jpg
# 7500 /kaggle/input/shopee-product-detection-open/test/test/test/c27210b7377ecec3408a4b2b68c76dee.jpg
# 7600 /kaggle/input/shopee-product-detection-open/test/test/test/368e9b5ea57533d946946e81796d3f38.jpg
# 7700 /kaggle/input/shopee-product-detection-open/test/test/test/904f0032277bc2862b1406dbbd4adcbb.jpg
# 7800 /kaggle/input/shopee-product-detection-open/test/test/test/351166efeafde5374dc5f5d861b5da51.jpg
# 7900 /kaggle/input/shopee-product-detection-open/test/test/test/99ba1441896b56da65a8a31021093755.jpg
# 8000 /kaggle/input/shopee-product-detection-open/test/test/test/4eb47841762a48fcb5c52ababad67858.jpg
# 8100 /kaggle/input/shopee-product-detection-open/test/test/test/c22dcbd4c24310971d00719b7aaab889.jpg
# 8200 /kaggle/input/shopee-product-detection-open/test/test/test/bdc9df6d03eca62b4ed8d57c35559b83.jpg
# 8300 /kaggle/input/shopee-product-detection-open/test/test/test/0d5e6140384125002c898ad71fa5e6cd.jpg
# 8400 /kaggle/input/shopee-product-detection-open/test/test/test/88dde68cd623f2842272e1afa6c8c50d.jpg
# 8500 /kaggle/input/shopee-product-detection-open/test/test/test/ddc39951c81d6468fae55e7b1d2d74e7.jpg
# 8600 /kaggle/input/shopee-product-detection-open/test/test/test/12a3d9502554802bb94316390a7a0c28.jpg
# 8700 /kaggle/input/shopee-product-detection-open/test/test/test/421cb2d08c708500d2d1dcfc806a4b33.jpg
# 8800 /kaggle/input/shopee-product-detection-open/test/test/test/75a0e83eea484e8b959d02c1c75ffc63.jpg
# 8900 /kaggle/input/shopee-product-detection-open/test/test/test/24f025fa01997060b962121d82b84083.jpg
# 9000 /kaggle/input/shopee-product-detection-open/test/test/test/d4ed2944e79fb588b575115d51412888.jpg
# 9100 /kaggle/input/shopee-product-detection-open/test/test/test/1da7d3b921676026281e29a03e7647e0.jpg
# 9200 /kaggle/input/shopee-product-detection-open/test/test/test/f7ed39945464bea6a9f63268a8f3bf1d.jpg
# 9300 /kaggle/input/shopee-product-detection-open/test/test/test/bd6c89eddfe90549ad417bc1030e3f07.jpg
# 9400 /kaggle/input/shopee-product-detection-open/test/test/test/f842de369bc020da65d65fc80e9f26f2.jpg
# 9500 /kaggle/input/shopee-product-detection-open/test/test/test/6f679fe23fc886bbf228f8ddcd7dde7f.jpg
# 9600 /kaggle/input/shopee-product-detection-open/test/test/test/f2babea1c59895081a8ca1a66e2e3139.jpg
# 9700 /kaggle/input/shopee-product-detection-open/test/test/test/801803c816b967feb4c10c3c797993db.jpg
# 9800 /kaggle/input/shopee-product-detection-open/test/test/test/f3f855966da3f9b47c9679b551731911.jpg
# 9900 /kaggle/input/shopee-product-detection-open/test/test/test/fbd2162c9291f98835924bdb422c933e.jpg
# 10000 /kaggle/input/shopee-product-detection-open/test/test/test/e9ae33679a75429fd9bd1dde90cfe285.jpg
# 10100 /kaggle/input/shopee-product-detection-open/test/test/test/ac760fffc10a81e54ed769b0f5ca950b.jpg
# 10200 /kaggle/input/shopee-product-detection-open/test/test/test/2001979679a9d4044562c49e0b4477a0.jpg
# 10300 /kaggle/input/shopee-product-detection-open/test/test/test/f6e34b4d65db808e9d4c27eb9895a400.jpg
# 10400 /kaggle/input/shopee-product-detection-open/test/test/test/20469943a1573e14088f8c8918934375.jpg
# 10500 /kaggle/input/shopee-product-detection-open/test/test/test/586502d76843293b4502a1615d2dbfc3.jpg
# 10600 /kaggle/input/shopee-product-detection-open/test/test/test/34f39bffa282d18b29599016ebd740ab.jpg
# 10700 /kaggle/input/shopee-product-detection-open/test/test/test/282e052b51fac102549884560820b6a3.jpg
# 10800 /kaggle/input/shopee-product-detection-open/test/test/test/ec0e570ab4c6715e458c0726bf20b782.jpg
# 10900 /kaggle/input/shopee-product-detection-open/test/test/test/d197fb80ef457a573f2c1f895f5daf68.jpg
# 11000 /kaggle/input/shopee-product-detection-open/test/test/test/73efdde8bedcceeeaea3a498894c8d0c.jpg
# 11100 /kaggle/input/shopee-product-detection-open/test/test/test/a6166d041580b59b2daf833add0aa513.jpg
# 11200 /kaggle/input/shopee-product-detection-open/test/test/test/ccc0048a6c75688c4625904e8401dd10.jpg
# 11300 /kaggle/input/shopee-product-detection-open/test/test/test/964db99720913c1bc7441d43f580273b.jpg
# 11400 /kaggle/input/shopee-product-detection-open/test/test/test/c7773b74d7159b43871cf4d8e69fe48a.jpg
# 11500 /kaggle/input/shopee-product-detection-open/test/test/test/fcca8012fa118322a3f3f52c75ae100a.jpg
# 11600 /kaggle/input/shopee-product-detection-open/test/test/test/12a165a2e4a352e9c9f1f3c0ef47ea98.jpg
# 11700 /kaggle/input/shopee-product-detection-open/test/test/test/6ab837e2f7cb790dd0830e403ce1a7e4.jpg
# 11800 /kaggle/input/shopee-product-detection-open/test/test/test/707da7eccb5aa8a38b0519c389e8cf1a.jpg
# 11900 /kaggle/input/shopee-product-detection-open/test/test/test/9e01c68a8eabd8eb9eee67cf784135bd.jpg
# 12000 /kaggle/input/shopee-product-detection-open/test/test/test/4cdc93ebfc46988bd2b1275f4977d8df.jpg
# 12100 /kaggle/input/shopee-product-detection-open/test/test/test/acb85d176cb7875b33214df26a82574a.jpg
# finished

# %%
# from torchvision import models
# import torch

# dir(models)

# %%
# num_ftrs = res_mod.fc.in_features
# res_mod.fc = nn.Linear(num_ftrs, 2)

# res_mod = res_mod.to(device)
# criterion = nn.CrossEntropyLoss()

# # Observe that all parameters are being optimized
# optimizer_ft = optim.SGD(res_mod.parameters(), lr=0.001, momentum=0.9)

# # Decay LR by a factor of 0.1 every 7 epochs
# exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# train_model(res_mod,criterion,exp_lr_scheduler,10)
